# %%
# !git clone https://github.com/abolfazlaghdaee/Irony_Detection
# Out:
# Cloning into 'Irony_Detection'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 110 (delta 12), reused 21 (delta 5), pack-reused 77 (from 1)
# Receiving objects: 100% (110/110), 83.57 MiB | 43.46 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# !ls
# Out:
# Irony_Detection

# %%
# %cd Irony_Detection
# Out:
# /kaggle/working/Irony_Detection

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
# Out:
# 2025-07-09 13:05:20.450130: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752066320.658721      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752066320.718450      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
input_dim = 1000
output_dim = 500
max_size = 200

# %%
#rnn based model

rnn_model = keras.Sequential()
rnn_model.add(keras.layers.Embedding(input_dim, output_dim, input_length= max_size))
rnn_model.add(keras.layers.SimpleRNN(110))
rnn_model.add(keras.layers.Dense(1, activation='sigmoid'))
rnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# I0000 00:00:1752066333.857650      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1752066333.858406      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
#LSTM based model

lstm_model = keras.Sequential()
lstm_model.add(keras.layers.Embedding(input_dim, output_dim, input_length= max_size))
lstm_model.add(keras.layers.LSTM(128,return_sequences=True))
lstm_model.add(keras.layers.Dropout(0.8))
lstm_model.add(keras.layers.LSTM(64,return_sequences=True))
lstm_model.add(keras.layers.Dropout(0.5))
lstm_model.add(keras.layers.LSTM(32,return_sequences=True))
lstm_model.add(keras.layers.Dropout(0.5))
lstm_model.add(keras.layers.LSTM(16,return_sequences=True))
lstm_model.add(keras.layers.Dropout(0.5))
lstm_model.add(keras.layers.LSTM(8))
lstm_model.add(keras.layers.Dense(1, activation='sigmoid'))
lstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#GRU Based Model

gru_model = keras.Sequential()
gru_model.add(keras.layers.Embedding(input_dim, output_dim, input_length= max_size))
gru_model.add(keras.layers.Bidirectional(keras.layers.GRU(100)))
gru_model.add(keras.layers.BatchNormalization())
gru_model.add(keras.layers.Dense(1, activation='sigmoid'))
gru_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
models = {
    # 'RNN': rnn_model,
    # 'LSTM': lstm_model,
    'GRU': gru_model
}

# %%
X_train = np.load('data/X_train_parsbert1.npy')
X_test = np.load('data/X_test_parsbert1.npy')
y_train = np.load('data/y_train.npy')
y_test = np.load('data/y_test.npy')

# %%
histories = []

for k, v in models.items():


  print(k)
  print("="*70)
  hist = v.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))

  histories.append(hist)
# Out:
# GRU
# ======================================================================
# Epoch 1/30
# I0000 00:00:1752066483.714680     112 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.6107 - loss: 0.6752 - val_accuracy: 0.5760 - val_loss: 0.6814
# Epoch 2/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 26s 71ms/step - accuracy: 0.6480 - loss: 0.6285 - val_accuracy: 0.5906 - val_loss: 0.7246
# Epoch 3/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.6538 - loss: 0.6243 - val_accuracy: 0.6434 - val_loss: 0.6185
# Epoch 4/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 26s 72ms/step - accuracy: 0.6614 - loss: 0.6152 - val_accuracy: 0.6540 - val_loss: 0.6496
# Epoch 5/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 26s 72ms/step - accuracy: 0.6739 - loss: 0.6019 - val_accuracy: 0.6087 - val_loss: 0.6520
# Epoch 6/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.6861 - loss: 0.5875 - val_accuracy: 0.6720 - val_loss: 0.6459
# Epoch 7/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.6861 - loss: 0.5861 - val_accuracy: 0.6853 - val_loss: 0.6379
# Epoch 8/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.6877 - loss: 0.5835 - val_accuracy: 0.7020 - val_loss: 0.5793
# Epoch 9/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7021 - loss: 0.5753 - val_accuracy: 0.7112 - val_loss: 0.5712
# Epoch 10/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7033 - loss: 0.5698 - val_accuracy: 0.7146 - val_loss: 0.5548
# Epoch 11/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7041 - loss: 0.5676 - val_accuracy: 0.7231 - val_loss: 0.5525
# Epoch 12/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7069 - loss: 0.5673 - val_accuracy: 0.7132 - val_loss: 0.5735
# Epoch 13/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7014 - loss: 0.5665 - val_accuracy: 0.7204 - val_loss: 0.5498
# Epoch 14/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7184 - loss: 0.5555 - val_accuracy: 0.7159 - val_loss: 0.5664
# Epoch 15/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7123 - loss: 0.5625 - val_accuracy: 0.7003 - val_loss: 0.5703
# Epoch 16/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7277 - loss: 0.5540 - val_accuracy: 0.7207 - val_loss: 0.5500
# Epoch 17/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7209 - loss: 0.5435 - val_accuracy: 0.7180 - val_loss: 0.5514
# Epoch 18/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7180 - loss: 0.5473 - val_accuracy: 0.7217 - val_loss: 0.5416
# Epoch 19/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7341 - loss: 0.5377 - val_accuracy: 0.7234 - val_loss: 0.5467
# Epoch 20/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7277 - loss: 0.5358 - val_accuracy: 0.7279 - val_loss: 0.5439
# Epoch 21/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7341 - loss: 0.5325 - val_accuracy: 0.7337 - val_loss: 0.5384
# Epoch 22/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7367 - loss: 0.5274 - val_accuracy: 0.7258 - val_loss: 0.5553
# Epoch 23/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7363 - loss: 0.5305 - val_accuracy: 0.7095 - val_loss: 0.5652
# Epoch 24/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7378 - loss: 0.5225 - val_accuracy: 0.7306 - val_loss: 0.5433
# Epoch 25/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7388 - loss: 0.5140 - val_accuracy: 0.7190 - val_loss: 0.5523
# Epoch 26/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7531 - loss: 0.5040 - val_accuracy: 0.7299 - val_loss: 0.5447
# Epoch 27/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7517 - loss: 0.5040 - val_accuracy: 0.7132 - val_loss: 0.5745
# Epoch 28/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7611 - loss: 0.4897 - val_accuracy: 0.7302 - val_loss: 0.5500
# Epoch 29/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7647 - loss: 0.4830 - val_accuracy: 0.7285 - val_loss: 0.5485
# Epoch 30/30
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 27s 73ms/step - accuracy: 0.7676 - loss: 0.4770 - val_accuracy: 0.7074 - val_loss: 0.5694

# %%
gru_model.evaluate(X_test, y_test)
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7102 - loss: 0.5602
# [0.5693774819374084, 0.707425057888031]
